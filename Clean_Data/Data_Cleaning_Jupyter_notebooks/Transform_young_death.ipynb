# %%
# Import our dependencies
import pandas as pd

# %%
#  Import and read the input csv
yd_df = pd.read_csv("young_deaths_cleaned.csv")
yd_df
# Out:
#     Country Name                               Series Name  2000 [YR2000]  \
# 0    Afghanistan    Survival to age 65, male (% of cohort)      48.209619
# 1    Afghanistan  Survival to age 65, female (% of cohort)      54.133867
# 2        Albania    Survival to age 65, male (% of cohort)      78.304781
# 3        Albania  Survival to age 65, female (% of cohort)      87.623860
# 4        Algeria    Survival to age 65, male (% of cohort)      72.944406
# ..           ...                                       ...            ...
# 357  Yemen, Rep.  Survival to age 65, female (% of cohort)      63.043049
# 358       Zambia    Survival to age 65, male (% of cohort)      23.724823
# 359       Zambia  Survival to age 65, female (% of cohort)      32.282970
# 360     Zimbabwe    Survival to age 65, male (% of cohort)      17.514188
# 361     Zimbabwe  Survival to age 65, female (% of cohort)      27.482299
#
#      2001 [YR2001]  2002 [YR2002]  2003 [YR2003]  2004 [YR2004]  \
# ...

# %%
yd_df = yd_df.drop(['Series Name'], 1)
yd_df
# Out:
# C:\Users\dsmel\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
#     Country Name  2000 [YR2000]  2001 [YR2001]  2002 [YR2002]  2003 [YR2003]  \
# 0    Afghanistan      48.209619      48.902877      49.596135      50.398152
# 1    Afghanistan      54.133867      54.853346      55.572824      56.429403
# 2        Albania      78.304781      79.202819      80.100857      80.293390
# 3        Albania      87.623860      88.032359      88.440858      88.605522
# 4        Algeria      72.944406      73.708181      74.471957      75.269949
# ..           ...            ...            ...            ...            ...
# 357  Yemen, Rep.      63.043049      63.804695      64.566341      65.381700
# 358       Zambia      23.724823      24.178367      24.631911      26.221801
# ...

# %%
yd_transform_df = yd_df.set_index('Country Name', 'Series Name').T
yd_transform_df
# Out:
# C:\Users\dsmel\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.set_index except for the argument 'keys' will be keyword-only
#   """Entry point for launching an IPython kernel.
# Country Name   Afghanistan  Afghanistan    Albania    Albania    Algeria  \
# 2000 [YR2000]    48.209619    54.133867  78.304781  87.623860  72.944406
# 2001 [YR2001]    48.902877    54.853346  79.202819  88.032359  73.708181
# 2002 [YR2002]    49.596135    55.572824  80.100857  88.440858  74.471957
# 2003 [YR2003]    50.398152    56.429403  80.293390  88.605522  75.269949
# 2004 [YR2004]    51.200169    57.285982  80.485923  88.770186  76.067942
# 2005 [YR2005]    52.002187    58.142561  80.678456  88.934850  76.865934
# 2006 [YR2006]    52.804204    58.999140  80.870989  89.099514  77.663927
# 2007 [YR2007]    53.606221    59.855719  81.063522  89.264178  78.461919
# ...

# %%
yd_transform_df.to_csv('yd_clean-transform.csv')

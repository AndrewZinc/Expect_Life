# %%
# Import our dependencies
import pandas as pd

# %%
#  Import and read the input csv
dps_df = pd.read_csv('../Raw_Data/daily-protein-supply-of-animal-origin-vs-plant-origin.csv')
dps_df

# %%
#  Import and read the updated input csv
dps_df = pd.read_csv('daily-protein-supply-animal-veg.csv')
dps_df
# Out:
#       Unnamed: 0    Entity  Year  \
# 0            559   Albania  2000
# 1            560   Albania  2001
# 2            561   Albania  2002
# 3            562   Albania  2003
# 4            563   Albania  2004
# ...          ...       ...   ...
# 4293       57466  Zimbabwe  2017
# 4294       57467  Zimbabwe  2018
# 4295       57468  Zimbabwe  2019
# 4296       57469  Zimbabwe  2020
# 4297       57470  Zimbabwe  2021
#
#       Daily protein supply of plant origin (FAO (2017))  \
# 0                                                 51.50
# 1                                                 51.74
# 2                                                 53.15
# 3                                                 48.74
# 4                                                 47.37
# ...                                                 ...
# 4293                                                NaN
# 4294                                                NaN
# ...

# %%
# Drop the extra columns
dps_df = dps_df.drop(['Code','Continent'], 1)

# %%
# Drop the udpated file index column
dps_df = dps_df.drop(['Unnamed: 0'], 1)
# Out:
# C:\Temp\ipykernel_11316\4267185393.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   dps_df = dps_df.drop(['Unnamed: 0'], 1)

# %%
dps_df
# Out:
#         Entity  Year  Daily protein supply of plant origin (FAO (2017))  \
# 0      Albania  2000                                              51.50
# 1      Albania  2001                                              51.74
# 2      Albania  2002                                              53.15
# 3      Albania  2003                                              48.74
# 4      Albania  2004                                              47.37
# ...        ...   ...                                                ...
# 4293  Zimbabwe  2017                                                NaN
# 4294  Zimbabwe  2018                                                NaN
# 4295  Zimbabwe  2019                                                NaN
# 4296  Zimbabwe  2020                                                NaN
# 4297  Zimbabwe  2021                                                NaN
#
#       Daily protein supply of animal origin (FAO (2017))
# ...

# %%
dps_df = dps_df[dps_df['Year']>=2000]
dps_df = dps_df[dps_df['Year']<=2022]
dps_df
# Out:
#         Entity  Year  Daily protein supply of plant origin (FAO (2017))  \
# 0      Albania  2000                                              51.50
# 1      Albania  2001                                              51.74
# 2      Albania  2002                                              53.15
# 3      Albania  2003                                              48.74
# 4      Albania  2004                                              47.37
# ...        ...   ...                                                ...
# 4293  Zimbabwe  2017                                                NaN
# 4294  Zimbabwe  2018                                                NaN
# 4295  Zimbabwe  2019                                                NaN
# 4296  Zimbabwe  2020                                                NaN
# 4297  Zimbabwe  2021                                                NaN
#
#       Daily protein supply of animal origin (FAO (2017))
# ...

# %%
# Open the master list of countries
countries_df = pd.read_csv('../Clean_Data/country_profile_urls.csv')
countries_df = countries_df.drop(['profile_url'], 1)
# Out:
# C:\Temp\ipykernel_11316\822363187.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   countries_df = countries_df.drop(['profile_url'], 1)

# %%
country_list = countries_df['country'].tolist()
country_list
# Out:
# ['Albania',
#  'Algeria',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Botswana',
#  'Brazil',
#  'British Virgin Islands',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Congo',
#  'Costa Rica',
#  "Côte d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Cyprus',
#  'Czechia',
#  'Democratic Republic of the Congo',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Equatorial Guinea',
#  'Estonia',
#  'Eswatini',
#  'Ethiopia',
#  'Fiji',
#  'Finland',
#  'France',
#  'Gabon',
#  'Gambia',
#  'Georgia',
# ...

# %%
# Create a list of Food Supply countries
ps_countries = dps_df['Entity'].tolist()
ps_countries
# Out:
# ['Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
# ...

# %%
# clean the FS data based on the SS country list
no_match = []

for country in ps_countries:
    if country in country_list:
        continue
    else:
        no_match.append(country)

# %%
# Likely need to do manual country name clean-up for accented characters and abbreviations.
no_match
# Out:
# ['American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'American Samoa',
#  'Anguilla',
#  'Anguilla',
#  'Anguilla',
#  'Anguilla',
#  'Anguilla',
#  'Anguilla',
#  'Anguilla',
#  'Anguilla',
#  'Anguilla',
#  'Anguilla',
#  'Anguilla',
#  'Anguilla',
#  'Anguilla',
#  'Anguilla',
#  'Anguilla',
#  'Anguilla',
#  'Anguilla',
#  'Anguilla',
#  'Anguilla',
#  'Anguilla',
#  'Anguilla',
#  'Anguilla',
#  'Antarctica',
#  'Bavaria',
#  'Brunei',
#  'Brunei',
#  'Brunei',
#  'Brunei',
#  'Brunei',
#  'Brunei',
#  'Brunei',
#  'Brunei',
#  'Brunei',
#  'Brunei',
#  'Brunei',
#  'Brunei',
#  'Brunei',
# ...

# %%
dps_clean_df = dps_df.drop(dps_df[dps_df['Entity'].isin(no_match)].index.tolist())
dps_clean_df
# Out:
#         Entity  Year  Daily protein supply of plant origin (FAO (2017))  \
# 0      Albania  2000                                              51.50
# 1      Albania  2001                                              51.74
# 2      Albania  2002                                              53.15
# 3      Albania  2003                                              48.74
# 4      Albania  2004                                              47.37
# ...        ...   ...                                                ...
# 4293  Zimbabwe  2017                                                NaN
# 4294  Zimbabwe  2018                                                NaN
# 4295  Zimbabwe  2019                                                NaN
# 4296  Zimbabwe  2020                                                NaN
# 4297  Zimbabwe  2021                                                NaN
#
#       Daily protein supply of animal origin (FAO (2017))
# ...

# %%
dps_df.to_csv('daily-protein-supply-animal-veg.csv')

# %%
#fsle_clean_transform_df = fsle_clean_df.set_index('Entity').T
#fsle_clean_transform_df

# %%
#fsle_clean_transform_df.to_csv('food_supply_life_expectancy_transform.csv')

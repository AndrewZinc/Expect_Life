# %%
# Import our dependencies
import pandas as pd

# %%
#  Import and read the input csv
fsle_df = pd.read_csv('../../Raw_Data/food-supply-vs-life-expectancy.csv', encoding='iso-8859-1')
fsle_df

# %%
#  Import and read the updated input csv
fsle_df = pd.read_csv('food_supply_life_expectancy.csv')
fsle_df
# Out:
#       Unnamed: 0          Entity  Year  \
# 0              0        Abkhazia  2015
# 1             51     Afghanistan  2000
# 2             52     Afghanistan  2001
# 3             53     Afghanistan  2002
# 4             54     Afghanistan  2003
# ...          ...             ...   ...
# 5094       58091        Zimbabwe  2015
# 5095       58092        Zimbabwe  2016
# 5096       58093        Zimbabwe  2017
# 5097       58094        Zimbabwe  2018
# 5098       58285  Ã
# land Islands  2015
#
#       Daily caloric supply (OWID based on UN FAO & historical sources)
# 0                                                   NaN
# 1                                                1790.0
# 2                                                1737.0
# 3                                                1826.0
# 4                                                1892.0
# ...                                                 ...
# 5094                                             1912.0
# ...

# %%
# Drop the population estimate column
fsle_df = fsle_df.drop(['Population (historical estimates)','Continent', 'Life expectancy - Sex: all - Age: at birth - Variant: estimates', 'Code'], 1)

# %%
# Drop the udpated file index column
fsle_df = fsle_df.drop(['Unnamed: 0'], 1)
# Out:
# C:\Temp\ipykernel_3436\3427511736.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   fsle_df = fsle_df.drop(['Unnamed: 0'], 1)

# %%
fsle_df
# Out:
#               Entity  Year  \
# 0           Abkhazia  2015
# 1        Afghanistan  2000
# 2        Afghanistan  2001
# 3        Afghanistan  2002
# 4        Afghanistan  2003
# ...              ...   ...
# 5094        Zimbabwe  2015
# 5095        Zimbabwe  2016
# 5096        Zimbabwe  2017
# 5097        Zimbabwe  2018
# 5098  Ã
# land Islands  2015
#
#       Daily caloric supply (OWID based on UN FAO & historical sources)
# 0                                                   NaN
# 1                                                1790.0
# 2                                                1737.0
# 3                                                1826.0
# 4                                                1892.0
# ...                                                 ...
# 5094                                             1912.0
# 5095                                             1885.0
# 5096                                             1891.0
# ...

# %%
fsle_df = fsle_df[fsle_df['Year']>=2000]
fsle_df = fsle_df[fsle_df['Year']<=2018]
fsle_df

# %%
# Open the master list of countries
countries_df = pd.read_csv('../../Clean_Data/master_country_list/country_profile_urls.csv')
countries_df = countries_df.drop(['profile_url'], 1)
# Out:
# C:\Temp\ipykernel_3436\1673923060.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   countries_df = countries_df.drop(['profile_url'], 1)

# %%
country_list = countries_df['country'].tolist()
country_list
# Out:
# ['Albania',
#  'Algeria',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Botswana',
#  'Brazil',
#  'British Virgin Islands',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Congo',
#  'Costa Rica',
#  "Côte d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Cyprus',
#  'Czechia',
#  'Democratic Republic of the Congo',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Equatorial Guinea',
#  'Estonia',
#  'Eswatini',
#  'Ethiopia',
#  'Fiji',
#  'Finland',
#  'France',
#  'Gabon',
#  'Gambia',
#  'Georgia',
# ...

# %%
# Create a list of Food Supply countries
fs_countries = fsle_df['Entity'].tolist()
fs_countries
# Out:
# ['Abkhazia',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Akrotiri and Dhekelia',
#  'Albania',
# ...

# %%
fsle_df.to_csv('food_supply_life_expectancy.csv', encoding='utf-8', index=False)

# %%
# clean the FS data based on the SS country list
no_match = []

for country in fs_countries:
    if country in country_list:
        continue
    else:
        no_match.append(country)

# %%
# Likely need to do manual country name clean-up for accented characters and abbreviations.
no_match
# Out:
# ['Abkhazia',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Africa (UN)',
#  'Akrotiri and Dhekelia',
#  'American Samoa',
# ...

# %%
fsle_clean_df = fsle_df.drop(fsle_df[fsle_df['Entity'].isin(no_match)].index.tolist())
fsle_clean_df
# Out:
#         Entity  Year  \
# 59     Albania  2000
# 60     Albania  2001
# 61     Albania  2002
# 62     Albania  2003
# 63     Albania  2004
# ...        ...   ...
# 5093  Zimbabwe  2014
# 5094  Zimbabwe  2015
# 5095  Zimbabwe  2016
# 5096  Zimbabwe  2017
# 5097  Zimbabwe  2018
#
#       Daily caloric supply (OWID based on UN FAO & historical sources)
# 59                                               2734.0
# 60                                               2803.0
# 61                                               2864.0
# 62                                               2772.0
# 63                                               2792.0
# ...                                                 ...
# 5093                                             1986.0
# 5094                                             1912.0
# 5095                                             1885.0
# 5096                                             1891.0
# 5097                                             1908.0
#
# ...

# %%
fsle_clean_df.to_csv('food_supply_life_expectancy.csv', encoding='utf-8', index=False)

# %%
#fsle_clean_transform_df = fsle_clean_df.set_index('Entity').T
#fsle_clean_transform_df

# %%
#fsle_clean_transform_df.to_csv('food_supply_life_expectancy_transform.csv')

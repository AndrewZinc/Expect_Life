# %%
# Import our dependencies
import pandas as pd

# %%
#  Import and read the input csv
dps_df = pd.read_csv('../Cluster_Analysis_Data/daily-protein-supply-animal-veg.csv')
dps_df
# Out:
#       Unnamed: 0    Entity  Year  \
# 0              0   Albania  2000
# 1              1   Albania  2001
# 2              2   Albania  2002
# 3              3   Albania  2003
# 4              4   Albania  2004
# ...          ...       ...   ...
# 4293        4293  Zimbabwe  2017
# 4294        4294  Zimbabwe  2018
# 4295        4295  Zimbabwe  2019
# 4296        4296  Zimbabwe  2020
# 4297        4297  Zimbabwe  2021
#
#       Daily protein supply of plant origin (FAO (2017))  \
# 0                                                 51.50
# 1                                                 51.74
# 2                                                 53.15
# 3                                                 48.74
# 4                                                 47.37
# ...                                                 ...
# 4293                                                NaN
# 4294                                                NaN
# 4295                                                NaN
# 4296                                                NaN
# 4297                                                NaN
#
#       Daily protein supply of animal origin (FAO (2017))
# 0                                                 38.89
# 1                                                 41.09
# 2                                                 44.77
# 3                                                 47.05
# 4                                                 47.90
# ...                                                 ...
# 4293                                                NaN
# 4294                                                NaN
# 4295                                                NaN
# 4296                                                NaN
# 4297                                                NaN
#
# [4298 rows x 5 columns]

# %%
# Drop the udpated file index column
dps_df = dps_df.drop(['Unnamed: 0'], 1)
# Out:
# C:\Temp\ipykernel_12912\4267185393.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   dps_df = dps_df.drop(['Unnamed: 0'], 1)

# %%
dps_df
# Out:
#         Entity  Year  Daily protein supply of plant origin (FAO (2017))  \
# 0      Albania  2000                                              51.50
# 1      Albania  2001                                              51.74
# 2      Albania  2002                                              53.15
# 3      Albania  2003                                              48.74
# 4      Albania  2004                                              47.37
# ...        ...   ...                                                ...
# 4293  Zimbabwe  2017                                                NaN
# 4294  Zimbabwe  2018                                                NaN
# 4295  Zimbabwe  2019                                                NaN
# 4296  Zimbabwe  2020                                                NaN
# 4297  Zimbabwe  2021                                                NaN
#
#       Daily protein supply of animal origin (FAO (2017))
# 0                                                 38.89
# 1                                                 41.09
# 2                                                 44.77
# 3                                                 47.05
# 4                                                 47.90
# ...                                                 ...
# 4293                                                NaN
# 4294                                                NaN
# 4295                                                NaN
# 4296                                                NaN
# 4297                                                NaN
#
# [4298 rows x 4 columns]

# %%
dps_df = dps_df[dps_df['Year']==2013]
dps_df
# Out:
#               Entity  Year  Daily protein supply of plant origin (FAO (2017))  \
# 13           Albania  2013                                              52.00
# 35           Algeria  2013                                              66.97
# 57    American Samoa  2013                                                NaN
# 79           Andorra  2013                                                NaN
# 101           Angola  2013                                              38.86
# ...              ...   ...                                                ...
# 4201       Venezuela  2013                                              34.89
# 4223         Vietnam  2013                                              50.56
# 4245           Yemen  2013                                              45.06
# 4267          Zambia  2013                                              45.99
# 4289        Zimbabwe  2013                                              36.59
#
#       Daily protein supply of animal origin (FAO (2017))
# 13                                                59.42
# 35                                                24.99
# 57                                                  NaN
# 79                                                  NaN
# 101                                               18.40
# ...                                                 ...
# 4201                                              38.12
# 4223                                              31.05
# 4245                                              13.88
# 4267                                               9.23
# 4289                                              11.76
#
# [195 rows x 4 columns]

# %%
# Open the master list of countries
countries_df = pd.read_csv('../Clean_Data/country_profile_urls.csv')
countries_df = countries_df.drop(['profile_url'], 1)

# %%
country_list = countries_df['country'].tolist()
country_list

# %%
# Create a list of Food Supply countries
ps_countries = dps_df['Entity'].tolist()
ps_countries

# %%
# clean the FS data based on the SS country list
no_match = []

for country in ps_countries:
    if country in country_list:
        continue
    else:
        no_match.append(country)

# %%
# Likely need to do manual country name clean-up for accented characters and abbreviations.
no_match

# %%
dps_clean_df = dps_df.drop(dps_df[dps_df['Entity'].isin(no_match)].index.tolist())
dps_clean_df

# %%
dps_clean_df = dps_df.dropna()
dps_clean_df
# Out:
#                    Entity  Year  \
# 13                Albania  2013
# 35                Algeria  2013
# 101                Angola  2013
# 146   Antigua and Barbuda  2013
# 168             Argentina  2013
# ...                   ...   ...
# 4201            Venezuela  2013
# 4223              Vietnam  2013
# 4245                Yemen  2013
# 4267               Zambia  2013
# 4289             Zimbabwe  2013
#
#       Daily protein supply of plant origin (FAO (2017))  \
# 13                                                52.00
# 35                                                66.97
# 101                                               38.86
# 146                                               26.88
# 168                                               35.70
# ...                                                 ...
# 4201                                              34.89
# 4223                                              50.56
# 4245                                              45.06
# 4267                                              45.99
# 4289                                              36.59
#
#       Daily protein supply of animal origin (FAO (2017))
# 13                                                59.42
# 35                                                24.99
# 101                                               18.40
# 146                                               56.83
# 168                                               66.94
# ...                                                 ...
# 4201                                              38.12
# 4223                                              31.05
# 4245                                              13.88
# 4267                                               9.23
# 4289                                              11.76
#
# [163 rows x 4 columns]

# %%
dps_df.to_csv('daily-protein-supply-animal-veg.csv', index=False)

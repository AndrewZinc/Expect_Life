# %%
# Import our dependencies
import pandas as pd

# %%
#  Import and read the input csv
css_df = pd.read_csv('country_social_security_systems-coded.csv')
css_df
# Out:
#                  country                                        system_type  \
# 0                Albania  ['Universal medical benefits','Social insuranc...
# 1                Algeria                        ['Social insurance system']
# 2                Andorra                        ['Social insurance system']
# 3                 Angola  ['Universal medical benefits','Social insuranc...
# 4    Antigua and Barbuda                        ['Social insurance system']
# ..                   ...                                                ...
# 178            Venezuela  ['Universal (birth grant and medical benefits)...
# 179              Vietnam                        ['Social insurance system']
# 180                Yemen  ['Universal medical benefits','Employer-liabil...
# 181               Zambia  ['Universal medical benefits','Employer-liabil...
# 182             Zimbabwe  ['Employer-liability system (cash sickness and...
#
#     profile_data_date
# 0        January 2018
# ...

# %%
# Drop the profile data date column
css_df = css_df.drop(['profile_data_date'], 1)
# Out:
# C:\Temp\ipykernel_12440\907431919.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   css_df = css_df.drop(['profile_data_date'], 1)

# %%
css_df
# Out:
#                  country                                        system_type
# 0                Albania  ['Universal medical benefits','Social insuranc...
# 1                Algeria                        ['Social insurance system']
# 2                Andorra                        ['Social insurance system']
# 3                 Angola  ['Universal medical benefits','Social insuranc...
# 4    Antigua and Barbuda                        ['Social insurance system']
# ..                   ...                                                ...
# 178            Venezuela  ['Universal (birth grant and medical benefits)...
# 179              Vietnam                        ['Social insurance system']
# 180                Yemen  ['Universal medical benefits','Employer-liabil...
# 181               Zambia  ['Universal medical benefits','Employer-liabil...
# 182             Zimbabwe  ['Employer-liability system (cash sickness and...
#
# [183 rows x 2 columns]

# %%
css_transform_df = css_df.set_index('country').T
css_transform_df
# Out:
# country                                                Albania  \
# system_type  ['Universal medical benefits','Social insuranc...
#
# country                          Algeria                      Andorra  \
# system_type  ['Social insurance system']  ['Social insurance system']
#
# country                                                 Angola  \
# system_type  ['Universal medical benefits','Social insuranc...
#
# country              Antigua and Barbuda  \
# system_type  ['Social insurance system']
#
# country                                              Argentina  \
# system_type  ['Universal medical benefits','Social insuranc...
#
# country                                                Armenia  \
# system_type  ['Universal (birth or adoption grant and medic...
#
# country                            Aruba  \
# system_type  ['Social insurance system']
#
# country                                              Australia  \
# ...

# %%
css_transform_df.to_csv('country_social_security_systems_transform.csv', index=False)

# %%
#  Import and read the input csv
css_df = pd.read_csv('./transformed/country_social_security_systems_transform-expand.csv')
css_df
# Out:
#                                               Albania  \
# 0   ['Universal medical benefits','Social insuranc...
# 1   ['Universal medical benefits','Social insuranc...
# 2   ['Universal medical benefits','Social insuranc...
# 3   ['Universal medical benefits','Social insuranc...
# 4   ['Universal medical benefits','Social insuranc...
# 5   ['Universal medical benefits','Social insuranc...
# 6   ['Universal medical benefits','Social insuranc...
# 7   ['Universal medical benefits','Social insuranc...
# 8   ['Universal medical benefits','Social insuranc...
# 9   ['Universal medical benefits','Social insuranc...
# 10  ['Universal medical benefits','Social insuranc...
# 11  ['Universal medical benefits','Social insuranc...
# 12  ['Universal medical benefits','Social insuranc...
# 13  ['Universal medical benefits','Social insuranc...
# 14  ['Universal medical benefits','Social insuranc...
# 15  ['Universal medical benefits','Social insuranc...
# ...

# %%
# Add a suffix to the column names
css_df = css_df.add_suffix('_CSS')
css_df
# Out:
#                                           Albania_CSS  \
# 0   ['Universal medical benefits','Social insuranc...
# 1   ['Universal medical benefits','Social insuranc...
# 2   ['Universal medical benefits','Social insuranc...
# 3   ['Universal medical benefits','Social insuranc...
# 4   ['Universal medical benefits','Social insuranc...
# 5   ['Universal medical benefits','Social insuranc...
# 6   ['Universal medical benefits','Social insuranc...
# 7   ['Universal medical benefits','Social insuranc...
# 8   ['Universal medical benefits','Social insuranc...
# 9   ['Universal medical benefits','Social insuranc...
# 10  ['Universal medical benefits','Social insuranc...
# 11  ['Universal medical benefits','Social insuranc...
# 12  ['Universal medical benefits','Social insuranc...
# 13  ['Universal medical benefits','Social insuranc...
# 14  ['Universal medical benefits','Social insuranc...
# 15  ['Universal medical benefits','Social insuranc...
# ...

# %%
css_df.to_csv('./transformed/country_social_security_systems_transform-expand.csv')

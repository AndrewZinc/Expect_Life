# %%
# Import our dependencies
import pandas as pd

# %%
#  Import and read the input csv
fsle_df = pd.read_csv('../Raw_Data/food-supply-vs-life-expectancy.csv', encoding='iso-8859-1')
fsle_df
# Out:
#                Entity      Code  Year  \
# 0            Abkhazia  OWID_ABK  2015
# 1         Afghanistan       AFG  1950
# 2         Afghanistan       AFG  1951
# 3         Afghanistan       AFG  1952
# 4         Afghanistan       AFG  1953
# ...               ...       ...   ...
# 58281        Zimbabwe       ZWE  1946
# 58282        Zimbabwe       ZWE  1947
# 58283        Zimbabwe       ZWE  1948
# 58284        Zimbabwe       ZWE  1949
# 58285  Ã
# land Islands       ALA  2015
#
#        Life expectancy - Sex: all - Age: at birth - Variant: estimates  \
# 0                                                    NaN
# 1                                                   27.7
# 2                                                   28.0
# 3                                                   28.4
# 4                                                   28.9
# ...                                                  ...
# 58281                                                NaN
# 58282                                                NaN
# 58283                                                NaN
# 58284                                                NaN
# 58285                                                NaN
#
#        Daily caloric supply (OWID based on UN FAO & historical sources)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 58281                                                NaN
# 58282                                                NaN
# 58283                                                NaN
# 58284                                                NaN
# 58285                                                NaN
#
#        Population (historical estimates) Continent
# 0                                    NaN      Asia
# 1                              7480464.0       NaN
# 2                              7571542.0       NaN
# 3                              7667534.0       NaN
# 4                              7764549.0       NaN
# ...                                  ...       ...
# 58281                          2526552.0       NaN
# 58282                          2575037.0       NaN
# 58283                          2624453.0       NaN
# 58284                          2681604.0       NaN
# 58285                                NaN    Europe
#
# [58286 rows x 7 columns]

# %%
#  Import and read the updated input csv
fsle_df = pd.read_csv('food_supply_life_expectancy.csv')
fsle_df
# Out:
#       Unnamed: 0    Entity Code  Year  \
# 0            642   Albania  ALB  2000
# 1            643   Albania  ALB  2001
# 2            644   Albania  ALB  2002
# 3            645   Albania  ALB  2003
# 4            646   Albania  ALB  2004
# ...          ...       ...  ...   ...
# 3845       58093  Zimbabwe  ZWE  2017
# 3846       58094  Zimbabwe  ZWE  2018
# 3847       58095  Zimbabwe  ZWE  2019
# 3848       58096  Zimbabwe  ZWE  2020
# 3849       58097  Zimbabwe  ZWE  2021
#
#       Life expectancy - Sex: all - Age: at birth - Variant: estimates  \
# 0                                                  75.4
# 1                                                  75.6
# 2                                                  75.9
# 3                                                  76.1
# 4                                                  76.4
# ...                                                 ...
# 3845                                               60.7
# 3846                                               61.4
# 3847                                               61.3
# 3848                                               61.1
# 3849                                               59.3
#
#       Daily caloric supply (OWID based on UN FAO & historical sources)
# 0                                                2734.0
# 1                                                2803.0
# 2                                                2864.0
# 3                                                2772.0
# 4                                                2792.0
# ...                                                 ...
# 3845                                             1891.0
# 3846                                             1908.0
# 3847                                                NaN
# 3848                                                NaN
# 3849                                                NaN
#
# [3850 rows x 6 columns]

# %%
# Drop the population estimate column
fsle_df = fsle_df.drop(['Population (historical estimates)','Continent'], 1)
# Out:
# C:\Temp\ipykernel_10476\2059819700.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   fsle_df = fsle_df.drop(['Population (historical estimates)','Continent'], 1)

# %%
# Drop the udpated file index column
fsle_df = fsle_df.drop(['Unnamed: 0', 'Code'], 1)
# Out:
# C:\Temp\ipykernel_10476\2844385646.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   fsle_df = fsle_df.drop(['Unnamed: 0', 'Code'], 1)

# %%
fsle_df
# Out:
#         Entity  Year  \
# 0      Albania  2000
# 1      Albania  2001
# 2      Albania  2002
# 3      Albania  2003
# 4      Albania  2004
# ...        ...   ...
# 3867  Zimbabwe  2017
# 3868  Zimbabwe  2018
# 3869  Zimbabwe  2019
# 3870  Zimbabwe  2020
# 3871  Zimbabwe  2021
#
#       Life expectancy - Sex: all - Age: at birth - Variant: estimates  \
# 0                                                  75.4
# 1                                                  75.6
# 2                                                  75.9
# 3                                                  76.1
# 4                                                  76.4
# ...                                                 ...
# 3867                                               60.7
# 3868                                               61.4
# 3869                                               61.3
# 3870                                               61.1
# 3871                                               59.3
#
#       Daily caloric supply (OWID based on UN FAO & historical sources)
# 0                                                2734.0
# 1                                                2803.0
# 2                                                2864.0
# 3                                                2772.0
# 4                                                2792.0
# ...                                                 ...
# 3867                                             1891.0
# 3868                                             1908.0
# 3869                                                NaN
# 3870                                                NaN
# 3871                                                NaN
#
# [3872 rows x 4 columns]

# %%
fsle_df = fsle_df[fsle_df['Year']>=2000]
fsle_df = fsle_df[fsle_df['Year']<=2022]
fsle_df
# Out:
#         Entity Code  Year  \
# 0      Albania  ALB  2000
# 1      Albania  ALB  2001
# 2      Albania  ALB  2002
# 3      Albania  ALB  2003
# 4      Albania  ALB  2004
# ...        ...  ...   ...
# 3845  Zimbabwe  ZWE  2017
# 3846  Zimbabwe  ZWE  2018
# 3847  Zimbabwe  ZWE  2019
# 3848  Zimbabwe  ZWE  2020
# 3849  Zimbabwe  ZWE  2021
#
#       Life expectancy - Sex: all - Age: at birth - Variant: estimates  \
# 0                                                  75.4
# 1                                                  75.6
# 2                                                  75.9
# 3                                                  76.1
# 4                                                  76.4
# ...                                                 ...
# 3845                                               60.7
# 3846                                               61.4
# 3847                                               61.3
# 3848                                               61.1
# 3849                                               59.3
#
#       Daily caloric supply (OWID based on UN FAO & historical sources)
# 0                                                2734.0
# 1                                                2803.0
# 2                                                2864.0
# 3                                                2772.0
# 4                                                2792.0
# ...                                                 ...
# 3845                                             1891.0
# 3846                                             1908.0
# 3847                                                NaN
# 3848                                                NaN
# 3849                                                NaN
#
# [3850 rows x 5 columns]

# %%
# Open the master list of countries
countries_df = pd.read_csv('../Clean_Data/country_profile_urls.csv')
countries_df = countries_df.drop(['profile_url'], 1)
# Out:
# C:\Temp\ipykernel_10476\822363187.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   countries_df = countries_df.drop(['profile_url'], 1)

# %%
country_list = countries_df['country'].tolist()
country_list
# Out:
# ['Albania',
#  'Algeria',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Botswana',
#  'Brazil',
#  'British Virgin Islands',
#  'Brunei Darussalam',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Congo',
#  'Costa Rica',
#  "Côte d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Cyprus',
#  'Czechia',
#  'Democratic Republic of the Congo',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Equatorial Guinea',
#  'Estonia',
#  'Eswatini',
#  'Ethiopia',
#  'Fiji',
#  'Finland',
#  'France',
#  'Gabon',
#  'Gambia',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Grenada',
#  'Guatemala',
#  'Guinea',
#  'Guinea-Bissau',
#  'Guyana',
#  'Haiti',
#  'Honduras',
#  'Hong Kong (China)',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Ireland',
#  'Isle of Man',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Jersey',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Kiribati',
#  'Kuwait',
#  'Kyrgyz Republic',
#  "Lao People's Democratic Republic",
#  'Latvia',
#  'Lebanon',
#  'Lesotho',
#  'Liberia',
#  'Libya',
#  'Liechtenstein',
#  'Lithuania',
#  'Luxembourg',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Mali',
#  'Malta',
#  'Marshall Islands',
#  'Mauritania',
#  'Mauritius',
#  'Mexico',
#  'Micronesia',
#  'Moldova',
#  'Monaco',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Namibia',
#  'Nepal',
#  'Netherlands',
#  'New Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'North Macedonia',
#  'Norway',
#  'Oman',
#  'Pakistan',
#  'Palau',
#  'Panama',
#  'Papua New Guinea',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Qatar',
#  'Romania',
#  'Russian Federation',
#  'Rwanda',
#  'Saint Lucia',
#  'Saint Vincent and the Grenadines',
#  'Samoa',
#  'San Marino',
#  'Sao Tome and Principe',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Seychelles',
#  'Sierra Leone',
#  'Singapore',
#  'Slovakia',
#  'Slovenia',
#  'Solomon Islands',
#  'South Africa',
#  'South Korea',
#  'Spain',
#  'Sri Lanka',
#  'Sudan',
#  'Suriname',
#  'Sweden',
#  'Switzerland',
#  'Syrian Arab Republic',
#  'Taiwan (China)',
#  'Tajikistan',
#  'Tanzania',
#  'Thailand',
#  'Togo',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Türkiye',
#  'Turkmenistan',
#  'Uganda',
#  'Ukraine',
#  'United Kingdom',
#  'United States of America',
#  'Uruguay',
#  'Uzbekistan',
#  'Vanuatu',
#  'Venezuela',
#  'Vietnam',
#  'Yemen',
#  'Zambia',
#  'Zimbabwe']

# %%
# Create a list of Food Supply countries
fs_countries = fsle_df['Entity'].tolist()
fs_countries
# Out:
# ['Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Albania',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Algeria',
#  'Andorra',
#  'Andorra',
#  'Andorra',
#  'Andorra',
#  'Andorra',
#  'Andorra',
#  'Andorra',
#  'Andorra',
#  'Andorra',
#  'Andorra',
#  'Andorra',
#  'Andorra',
#  'Andorra',
#  'Andorra',
#  'Andorra',
#  'Andorra',
#  'Andorra',
#  'Andorra',
#  'Andorra',
#  'Andorra',
#  'Andorra',
#  'Andorra',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Angola',
#  'Antigua and Barbuda',
#  'Antigua and Barbuda',
#  'Antigua and Barbuda',
#  'Antigua and Barbuda',
#  'Antigua and Barbuda',
#  'Antigua and Barbuda',
#  'Antigua and Barbuda',
#  'Antigua and Barbuda',
#  'Antigua and Barbuda',
#  'Antigua and Barbuda',
#  'Antigua and Barbuda',
#  'Antigua and Barbuda',
#  'Antigua and Barbuda',
#  'Antigua and Barbuda',
#  'Antigua and Barbuda',
#  'Antigua and Barbuda',
#  'Antigua and Barbuda',
#  'Antigua and Barbuda',
#  'Antigua and Barbuda',
#  'Antigua and Barbuda',
#  'Antigua and Barbuda',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Armenia',
#  'Armenia',
#  'Armenia',
#  'Armenia',
#  'Armenia',
#  'Armenia',
#  'Armenia',
#  'Armenia',
#  'Armenia',
#  'Armenia',
#  'Armenia',
#  'Armenia',
#  'Armenia',
#  'Armenia',
#  'Armenia',
#  'Armenia',
#  'Armenia',
#  'Armenia',
#  'Armenia',
#  'Armenia',
#  'Armenia',
#  'Armenia',
#  'Aruba',
#  'Aruba',
#  'Aruba',
#  'Aruba',
#  'Aruba',
#  'Aruba',
#  'Aruba',
#  'Aruba',
#  'Aruba',
#  'Aruba',
#  'Aruba',
#  'Aruba',
#  'Aruba',
#  'Aruba',
#  'Aruba',
#  'Aruba',
#  'Aruba',
#  'Aruba',
#  'Aruba',
#  'Aruba',
#  'Aruba',
#  'Aruba',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Australia',
#  'Austria',
#  'Austria',
#  'Austria',
#  'Austria',
#  'Austria',
#  'Austria',
#  'Austria',
#  'Austria',
#  'Austria',
#  'Austria',
#  'Austria',
#  'Austria',
#  'Austria',
#  'Austria',
#  'Austria',
#  'Austria',
#  'Austria',
#  'Austria',
#  'Austria',
#  'Austria',
#  'Austria',
#  'Austria',
#  'Azerbaijan',
#  'Azerbaijan',
#  'Azerbaijan',
#  'Azerbaijan',
#  'Azerbaijan',
#  'Azerbaijan',
#  'Azerbaijan',
#  'Azerbaijan',
#  'Azerbaijan',
#  'Azerbaijan',
#  'Azerbaijan',
#  'Azerbaijan',
#  'Azerbaijan',
#  'Azerbaijan',
#  'Azerbaijan',
#  'Azerbaijan',
#  'Azerbaijan',
#  'Azerbaijan',
#  'Azerbaijan',
#  'Azerbaijan',
#  'Azerbaijan',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahamas',
#  'Bahamas',
#  'Bahamas',
#  'Bahamas',
#  'Bahamas',
#  'Bahamas',
#  'Bahamas',
#  'Bahamas',
#  'Bahamas',
#  'Bahamas',
#  'Bahamas',
#  'Bahamas',
#  'Bahamas',
#  'Bahamas',
#  'Bahamas',
#  'Bahamas',
#  'Bahamas',
#  'Bahamas',
#  'Bahamas',
#  'Bahamas',
#  'Bahamas',
#  'Bahrain',
#  'Bahrain',
#  'Bahrain',
#  'Bahrain',
#  'Bahrain',
#  'Bahrain',
#  'Bahrain',
#  'Bahrain',
#  'Bahrain',
#  'Bahrain',
#  'Bahrain',
#  'Bahrain',
#  'Bahrain',
#  'Bahrain',
#  'Bahrain',
#  'Bahrain',
#  'Bahrain',
#  'Bahrain',
#  'Bahrain',
#  'Bahrain',
#  'Bahrain',
#  'Bahrain',
#  'Bangladesh',
#  'Bangladesh',
#  'Bangladesh',
#  'Bangladesh',
#  'Bangladesh',
#  'Bangladesh',
#  'Bangladesh',
#  'Bangladesh',
#  'Bangladesh',
#  'Bangladesh',
#  'Bangladesh',
#  'Bangladesh',
#  'Bangladesh',
#  'Bangladesh',
#  'Bangladesh',
#  'Bangladesh',
#  'Bangladesh',
#  'Bangladesh',
#  'Bangladesh',
#  'Bangladesh',
#  'Bangladesh',
#  'Bangladesh',
#  'Barbados',
#  'Barbados',
#  'Barbados',
#  'Barbados',
#  'Barbados',
#  'Barbados',
#  'Barbados',
#  'Barbados',
#  'Barbados',
#  'Barbados',
#  'Barbados',
#  'Barbados',
#  'Barbados',
#  'Barbados',
#  'Barbados',
#  'Barbados',
#  'Barbados',
#  'Barbados',
#  'Barbados',
#  'Barbados',
#  'Barbados',
#  'Barbados',
#  'Belarus',
#  'Belarus',
#  'Belarus',
#  'Belarus',
#  'Belarus',
#  'Belarus',
#  'Belarus',
#  'Belarus',
#  'Belarus',
#  'Belarus',
#  'Belarus',
#  'Belarus',
#  'Belarus',
#  'Belarus',
#  'Belarus',
#  'Belarus',
#  'Belarus',
#  'Belarus',
#  'Belarus',
#  'Belarus',
#  'Belarus',
#  'Belarus',
#  'Belgium',
#  'Belgium',
#  'Belgium',
#  'Belgium',
#  'Belgium',
#  'Belgium',
#  'Belgium',
#  'Belgium',
#  'Belgium',
#  'Belgium',
#  'Belgium',
#  'Belgium',
#  'Belgium',
#  'Belgium',
#  'Belgium',
#  'Belgium',
#  'Belgium',
#  'Belgium',
#  'Belgium',
#  'Belgium',
#  'Belgium',
#  'Belgium',
#  'Belize',
#  'Belize',
#  'Belize',
#  'Belize',
#  'Belize',
#  'Belize',
#  'Belize',
#  'Belize',
#  'Belize',
#  'Belize',
#  'Belize',
#  'Belize',
#  'Belize',
#  'Belize',
#  'Belize',
#  'Belize',
#  'Belize',
#  'Belize',
#  'Belize',
#  'Belize',
#  'Belize',
#  'Belize',
#  'Benin',
#  'Benin',
#  'Benin',
#  'Benin',
#  'Benin',
#  'Benin',
#  'Benin',
#  'Benin',
#  'Benin',
#  'Benin',
#  'Benin',
#  'Benin',
#  'Benin',
#  'Benin',
#  'Benin',
#  'Benin',
#  'Benin',
#  'Benin',
#  'Benin',
#  'Benin',
#  'Benin',
#  'Benin',
#  'Bermuda',
#  'Bermuda',
#  'Bermuda',
#  'Bermuda',
#  'Bermuda',
#  'Bermuda',
#  'Bermuda',
#  'Bermuda',
#  'Bermuda',
#  'Bermuda',
#  'Bermuda',
#  'Bermuda',
#  'Bermuda',
#  'Bermuda',
#  'Bermuda',
#  'Bermuda',
#  'Bermuda',
#  'Bermuda',
#  'Bermuda',
#  'Bermuda',
#  'Bermuda',
#  'Bermuda',
#  'Bhutan',
#  'Bhutan',
#  'Bhutan',
#  'Bhutan',
#  'Bhutan',
#  'Bhutan',
#  'Bhutan',
#  'Bhutan',
#  'Bhutan',
#  'Bhutan',
#  'Bhutan',
#  'Bhutan',
#  'Bhutan',
#  'Bhutan',
#  'Bhutan',
#  'Bhutan',
#  'Bhutan',
#  'Bhutan',
#  'Bhutan',
#  'Bhutan',
#  'Bhutan',
#  'Bhutan',
#  'Bolivia',
#  'Bolivia',
#  'Bolivia',
#  'Bolivia',
#  'Bolivia',
#  'Bolivia',
#  'Bolivia',
#  'Bolivia',
#  'Bolivia',
#  'Bolivia',
#  'Bolivia',
#  'Bolivia',
#  'Bolivia',
#  'Bolivia',
#  'Bolivia',
#  'Bolivia',
#  'Bolivia',
#  'Bolivia',
#  'Bolivia',
#  'Bolivia',
#  'Bolivia',
#  'Bolivia',
#  'Botswana',
#  'Botswana',
#  'Botswana',
#  'Botswana',
#  'Botswana',
#  'Botswana',
#  'Botswana',
#  'Botswana',
#  'Botswana',
#  'Botswana',
#  'Botswana',
#  'Botswana',
#  'Botswana',
#  'Botswana',
#  'Botswana',
#  'Botswana',
#  'Botswana',
#  'Botswana',
#  'Botswana',
#  'Botswana',
#  'Botswana',
#  'Botswana',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'British Virgin Islands',
#  'British Virgin Islands',
#  'British Virgin Islands',
#  'British Virgin Islands',
#  'British Virgin Islands',
#  'British Virgin Islands',
#  'British Virgin Islands',
#  'British Virgin Islands',
#  'British Virgin Islands',
#  'British Virgin Islands',
#  'British Virgin Islands',
#  'British Virgin Islands',
#  'British Virgin Islands',
#  'British Virgin Islands',
#  'British Virgin Islands',
#  'British Virgin Islands',
#  'British Virgin Islands',
#  'British Virgin Islands',
#  'British Virgin Islands',
#  'British Virgin Islands',
#  'British Virgin Islands',
#  'British Virgin Islands',
#  'Bulgaria',
#  'Bulgaria',
#  'Bulgaria',
#  'Bulgaria',
#  'Bulgaria',
#  'Bulgaria',
#  'Bulgaria',
#  'Bulgaria',
#  'Bulgaria',
#  'Bulgaria',
#  'Bulgaria',
#  'Bulgaria',
#  'Bulgaria',
#  'Bulgaria',
#  'Bulgaria',
#  'Bulgaria',
#  'Bulgaria',
#  'Bulgaria',
#  'Bulgaria',
#  'Bulgaria',
#  'Bulgaria',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burkina Faso',
#  'Burkina Faso',
#  'Burkina Faso',
#  'Burkina Faso',
#  'Burkina Faso',
#  'Burkina Faso',
#  'Burkina Faso',
#  'Burkina Faso',
#  'Burkina Faso',
#  'Burkina Faso',
#  'Burkina Faso',
#  'Burkina Faso',
#  'Burkina Faso',
#  'Burkina Faso',
#  'Burkina Faso',
#  'Burkina Faso',
#  'Burkina Faso',
#  'Burkina Faso',
#  'Burkina Faso',
#  'Burkina Faso',
#  'Burkina Faso',
#  'Burundi',
#  'Burundi',
#  'Burundi',
#  'Burundi',
#  'Burundi',
#  'Burundi',
#  'Burundi',
#  'Burundi',
#  'Burundi',
#  'Burundi',
#  'Burundi',
#  'Burundi',
#  'Burundi',
#  'Burundi',
#  'Burundi',
#  'Burundi',
#  'Burundi',
#  'Burundi',
#  'Burundi',
#  'Burundi',
#  'Burundi',
#  'Burundi',
#  'Cabo Verde',
#  'Cabo Verde',
#  'Cabo Verde',
#  'Cabo Verde',
#  'Cabo Verde',
#  'Cabo Verde',
#  'Cabo Verde',
#  'Cabo Verde',
#  'Cabo Verde',
#  'Cabo Verde',
#  'Cabo Verde',
#  'Cabo Verde',
#  'Cabo Verde',
#  'Cabo Verde',
#  'Cabo Verde',
#  'Cabo Verde',
#  'Cabo Verde',
#  'Cabo Verde',
#  'Cabo Verde',
#  'Cabo Verde',
#  'Cabo Verde',
#  'Cabo Verde',
#  'Cambodia',
#  'Cambodia',
#  'Cambodia',
#  'Cambodia',
#  'Cambodia',
#  'Cambodia',
#  'Cambodia',
#  'Cambodia',
#  'Cambodia',
#  'Cambodia',
#  'Cambodia',
#  'Cambodia',
#  'Cambodia',
#  'Cambodia',
#  'Cambodia',
#  'Cambodia',
#  'Cambodia',
#  'Cambodia',
#  'Cambodia',
#  'Cambodia',
#  'Cambodia',
#  'Cambodia',
#  'Cameroon',
#  'Cameroon',
#  'Cameroon',
#  'Cameroon',
#  'Cameroon',
#  'Cameroon',
#  'Cameroon',
#  'Cameroon',
#  'Cameroon',
#  'Cameroon',
#  'Cameroon',
#  'Cameroon',
#  'Cameroon',
#  'Cameroon',
#  'Cameroon',
#  'Cameroon',
#  'Cameroon',
#  'Cameroon',
#  'Cameroon',
#  'Cameroon',
#  'Cameroon',
#  'Cameroon',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Canada',
#  'Central African Republic',
#  'Central African Republic',
#  'Central African Republic',
#  'Central African Republic',
#  'Central African Republic',
#  'Central African Republic',
#  'Central African Republic',
#  'Central African Republic',
#  'Central African Republic',
#  'Central African Republic',
#  'Central African Republic',
#  'Central African Republic',
#  'Central African Republic',
#  'Central African Republic',
#  'Central African Republic',
#  'Central African Republic',
#  'Central African Republic',
#  'Central African Republic',
#  'Central African Republic',
#  'Central African Republic',
#  'Central African Republic',
#  'Central African Republic',
#  'Chad',
#  'Chad',
#  'Chad',
#  'Chad',
#  'Chad',
#  'Chad',
#  'Chad',
#  'Chad',
#  'Chad',
#  'Chad',
#  'Chad',
#  'Chad',
#  'Chad',
#  'Chad',
#  'Chad',
#  'Chad',
#  'Chad',
#  'Chad',
#  'Chad',
#  'Chad',
#  'Chad',
#  'Chad',
#  'Chile',
#  'Chile',
#  'Chile',
#  'Chile',
#  'Chile',
#  'Chile',
#  'Chile',
#  'Chile',
#  'Chile',
#  'Chile',
#  'Chile',
#  'Chile',
#  'Chile',
#  'Chile',
#  'Chile',
#  'Chile',
#  'Chile',
#  'Chile',
#  'Chile',
#  'Chile',
#  'Chile',
#  'Chile',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'Colombia',
#  'Colombia',
#  'Colombia',
#  'Colombia',
#  'Colombia',
#  'Colombia',
#  'Colombia',
#  'Colombia',
#  'Colombia',
#  'Colombia',
#  'Colombia',
#  'Colombia',
#  'Colombia',
#  'Colombia',
#  'Colombia',
#  'Colombia',
#  'Colombia',
#  'Colombia',
#  'Colombia',
#  'Colombia',
#  'Colombia',
#  'Colombia',
#  'Congo',
#  'Congo',
#  'Congo',
#  'Congo',
#  'Congo',
#  'Congo',
#  'Congo',
#  'Congo',
#  'Congo',
#  'Congo',
#  'Congo',
#  'Congo',
#  'Congo',
#  'Congo',
#  'Congo',
#  'Congo',
#  'Congo',
#  'Congo',
#  'Congo',
#  'Congo',
#  'Congo',
#  'Congo',
#  'Costa Rica',
#  'Costa Rica',
#  'Costa Rica',
#  'Costa Rica',
#  'Costa Rica',
#  'Costa Rica',
#  'Costa Rica',
#  'Costa Rica',
#  'Costa Rica',
#  'Costa Rica',
#  'Costa Rica',
#  'Costa Rica',
#  'Costa Rica',
#  'Costa Rica',
#  'Costa Rica',
#  'Costa Rica',
#  'Costa Rica',
#  'Costa Rica',
#  'Costa Rica',
#  'Costa Rica',
#  'Costa Rica',
#  'Costa Rica',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Croatia',
#  'Cuba',
#  'Cuba',
#  'Cuba',
#  'Cuba',
#  'Cuba',
#  'Cuba',
#  'Cuba',
#  'Cuba',
#  'Cuba',
#  'Cuba',
#  'Cuba',
#  'Cuba',
#  'Cuba',
#  'Cuba',
#  'Cuba',
#  'Cuba',
#  'Cuba',
#  'Cuba',
#  'Cuba',
#  'Cuba',
#  'Cuba',
#  'Cuba',
#  'Cyprus',
#  'Cyprus',
#  'Cyprus',
#  'Cyprus',
#  'Cyprus',
#  'Cyprus',
#  'Cyprus',
#  'Cyprus',
#  'Cyprus',
#  'Cyprus',
#  'Cyprus',
#  'Cyprus',
#  'Cyprus',
#  'Cyprus',
#  'Cyprus',
#  'Cyprus',
#  'Cyprus',
#  'Cyprus',
#  'Cyprus',
#  'Cyprus',
#  'Cyprus',
#  'Cyprus',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Czechia',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Democratic Republic of the Congo',
#  'Denmark',
#  'Denmark',
#  'Denmark',
#  'Denmark',
#  'Denmark',
#  'Denmark',
#  'Denmark',
#  'Denmark',
#  'Denmark',
#  'Denmark',
#  'Denmark',
#  'Denmark',
#  'Denmark',
#  'Denmark',
#  'Denmark',
#  'Denmark',
#  'Denmark',
#  'Denmark',
#  'Denmark',
#  'Denmark',
#  'Denmark',
#  'Denmark',
#  'Djibouti',
#  'Djibouti',
#  'Djibouti',
#  'Djibouti',
#  'Djibouti',
#  'Djibouti',
#  'Djibouti',
#  'Djibouti',
#  'Djibouti',
#  'Djibouti',
#  ...]

# %%
# clean the FS data based on the SS country list
no_match = []

for country in fs_countries:
    if country in country_list:
        continue
    else:
        no_match.append(country)

# %%
# Likely need to do manual country name clean-up for accented characters and abbreviations.
no_match
# Out:
# []

# %%
fsle_clean_df = fsle_df.drop(fsle_df[fsle_df['Entity'].isin(no_match)].index.tolist())
fsle_clean_df
# Out:
#          Entity Code  Year  \
# 642     Albania  ALB  2000
# 643     Albania  ALB  2001
# 644     Albania  ALB  2002
# 645     Albania  ALB  2003
# 646     Albania  ALB  2004
# ...         ...  ...   ...
# 58093  Zimbabwe  ZWE  2017
# 58094  Zimbabwe  ZWE  2018
# 58095  Zimbabwe  ZWE  2019
# 58096  Zimbabwe  ZWE  2020
# 58097  Zimbabwe  ZWE  2021
#
#        Life expectancy - Sex: all - Age: at birth - Variant: estimates  \
# 642                                                 75.4
# 643                                                 75.6
# 644                                                 75.9
# 645                                                 76.1
# 646                                                 76.4
# ...                                                  ...
# 58093                                               60.7
# 58094                                               61.4
# 58095                                               61.3
# 58096                                               61.1
# 58097                                               59.3
#
#        Daily caloric supply (OWID based on UN FAO & historical sources)
# 642                                               2734.0
# 643                                               2803.0
# 644                                               2864.0
# 645                                               2772.0
# 646                                               2792.0
# ...                                                  ...
# 58093                                             1891.0
# 58094                                             1908.0
# 58095                                                NaN
# 58096                                                NaN
# 58097                                                NaN
#
# [3850 rows x 5 columns]

# %%
fsle_clean_df.to_csv('food_supply_life_expectancy.csv')

# %%
#fsle_clean_transform_df = fsle_clean_df.set_index('Entity').T
#fsle_clean_transform_df
# Out:
# Entity                                             Albania Albania Albania  \
# Code                                                   ALB     ALB     ALB
# Year                                                  2000    2001    2002
# Life expectancy - Sex: all - Age: at birth - Va...    75.4    75.6    75.9
# Daily caloric supply (OWID based on UN FAO & hi...  2734.0  2803.0  2864.0
#
# Entity                                             Albania Albania Albania  \
# Code                                                   ALB     ALB     ALB
# Year                                                  2003    2004    2005
# Life expectancy - Sex: all - Age: at birth - Va...    76.1    76.4    76.6
# Daily caloric supply (OWID based on UN FAO & hi...  2772.0  2792.0  2874.0
#
# Entity                                             Albania Albania Albania  \
# Code                                                   ALB     ALB     ALB
# Year                                                  2006    2007    2008
# Life expectancy - Sex: all - Age: at birth - Va...    76.8    77.5    77.7
# Daily caloric supply (OWID based on UN FAO & hi...  2855.0  2860.0  2947.0
#
# Entity                                             Albania  ... Zimbabwe  \
# Code                                                   ALB  ...      ZWE
# Year                                                  2009  ...     2012
# Life expectancy - Sex: all - Age: at birth - Va...    77.8  ...     55.6
# Daily caloric supply (OWID based on UN FAO & hi...  2993.0  ...   2197.0
#
# Entity                                             Zimbabwe Zimbabwe Zimbabwe  \
# Code                                                    ZWE      ZWE      ZWE
# Year                                                   2013     2014     2015
# Life expectancy - Sex: all - Age: at birth - Va...     57.5     58.8     59.6
# Daily caloric supply (OWID based on UN FAO & hi...   2110.0   1986.0   1912.0
#
# Entity                                             Zimbabwe Zimbabwe Zimbabwe  \
# Code                                                    ZWE      ZWE      ZWE
# Year                                                   2016     2017     2018
# Life expectancy - Sex: all - Age: at birth - Va...     60.3     60.7     61.4
# Daily caloric supply (OWID based on UN FAO & hi...   1885.0   1891.0   1908.0
#
# Entity                                             Zimbabwe Zimbabwe Zimbabwe
# Code                                                    ZWE      ZWE      ZWE
# Year                                                   2019     2020     2021
# Life expectancy - Sex: all - Age: at birth - Va...     61.3     61.1     59.3
# Daily caloric supply (OWID based on UN FAO & hi...      NaN      NaN      NaN
#
# [4 rows x 3850 columns]

# %%
#fsle_clean_transform_df.to_csv('food_supply_life_expectancy_transform.csv')

# %%
#import dependencies
import pandas as pd
import numpy as np

# %%
file_dir = 'Resources/Health_expenditures.csv'

# %%
health_df = pd.read_csv(file_dir)
health_df.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                          Series Name        Series Code  \
# 0  Domestic general government health expenditure...  SH.XPD.GHED.PC.CD
# 1  Domestic general government health expenditure...  SH.XPD.GHED.GE.ZS
# 2  Domestic general government health expenditure...  SH.XPD.GHED.GD.ZS
# 3  Domestic general government health expenditure...  SH.XPD.GHED.CH.ZS
# 4  Domestic private health expenditure (% of curr...  SH.XPD.PVTD.CH.ZS
#
#   2000 [YR2000] 2001 [YR2001] 2002 [YR2002] 2003 [YR2003] 2004 [YR2004]  \
# 0            ..            ..    0.14087316    1.24027791    1.12990194
# 1            ..            ..    1.21245611    5.45767879    3.60296822
# 2            ..            ..    0.08418062    0.65096337     0.5429256
# ...

# %%
health_df.columns.tolist()
# Out:
# ['Country Name',
#  'Country Code',
#  'Series Name',
#  'Series Code',
#  '2000 [YR2000]',
#  '2001 [YR2001]',
#  '2002 [YR2002]',
#  '2003 [YR2003]',
#  '2004 [YR2004]',
#  '2005 [YR2005]',
#  '2006 [YR2006]',
#  '2007 [YR2007]',
#  '2008 [YR2008]',
#  '2009 [YR2009]',
#  '2010 [YR2010]',
#  '2011 [YR2011]',
#  '2012 [YR2012]',
#  '2013 [YR2013]',
#  '2014 [YR2014]',
#  '2015 [YR2015]',
#  '2016 [YR2016]',
#  '2017 [YR2017]',
#  '2018 [YR2018]',
#  '2019 [YR2019]',
#  '2020 [YR2020]',
#  '2021 [YR2021]']

# %%
def clean_df(df):
    df= dict(df) #create a non-destructive copy

# %%
#determine number of null values in dataframe
health_df.isnull()
# Out:
#       Country Name  Country Code  Series Name  Series Code  2000 [YR2000]  \
# 0            False         False        False        False          False
# 1            False         False        False        False          False
# 2            False         False        False        False          False
# 3            False         False        False        False          False
# 4            False         False        False        False          False
# ...            ...           ...          ...          ...            ...
# 1736          True          True         True         True           True
# 1737          True          True         True         True           True
# 1738          True          True         True         True           True
# 1739         False          True         True         True           True
# 1740         False          True         True         True           True
#
#       2001 [YR2001]  2002 [YR2002]  2003 [YR2003]  2004 [YR2004]  \
# ...

# %%
health_df = health_df.dropna()
health_df.dropna(axis = 1, how = 'all')
# Out:
#      Country Name Country Code  \
# 0     Afghanistan          AFG
# 1     Afghanistan          AFG
# 2     Afghanistan          AFG
# 3     Afghanistan          AFG
# 4     Afghanistan          AFG
# ...           ...          ...
# 1731     Zimbabwe          ZWE
# 1732     Zimbabwe          ZWE
# 1733     Zimbabwe          ZWE
# 1734     Zimbabwe          ZWE
# 1735     Zimbabwe          ZWE
#
#                                             Series Name        Series Code  \
# 0     Domestic general government health expenditure...  SH.XPD.GHED.PC.CD
# 1     Domestic general government health expenditure...  SH.XPD.GHED.GE.ZS
# 2     Domestic general government health expenditure...  SH.XPD.GHED.GD.ZS
# 3     Domestic general government health expenditure...  SH.XPD.GHED.CH.ZS
# 4     Domestic private health expenditure (% of curr...  SH.XPD.PVTD.CH.ZS
# ...                                                 ...                ...
# ...

# %%
health_df["Series Name"] = health_df["Series Name"].to_string(header = False, index = False)
health_df["Series Name"]
# Out:
# 0       Domestic general government health expenditure...
# 1       Domestic general government health expenditure...
# 2       Domestic general government health expenditure...
# 3       Domestic general government health expenditure...
# 4       Domestic general government health expenditure...
#                               ...
# 1731    Domestic general government health expenditure...
# 1732    Domestic general government health expenditure...
# 1733    Domestic general government health expenditure...
# 1734    Domestic general government health expenditure...
# 1735    Domestic general government health expenditure...
# Name: Series Name, Length: 1736, dtype: object

# %%
def parse_spending(item):
    if (item == 'Domestic general government health expenditure per capita (current US$)'):
        item = 'govt expenditure per capita in USD'
    elif (item == 'Domestic general government health expenditure (% of general government expenditure)'):
        item = 'govt health expenditure as % of total'
    elif (item == 'Domestic general government health expenditure (% of GDP)'):
        item = 'govt as % GDP'
    elif (item == 'Domestic general government health expenditure (% of current health expenditure)'):
        item = 'govt as % total health'
    elif (item == 'Domestic private health expenditure (% of current health expenditure)'):
        item = 'private as % total health'
    elif (item == 'Domestic private health expenditure per capita (current US$)'):
        item = 'private per capita in USD'
    elif (item == 'Domestic private health expenditure per capita, PPP (current international $)'):
        item = 'private in international $'
    return item

# %%
health_df
# Out:
#      Country Name Country Code  \
# 0     Afghanistan          AFG
# 1     Afghanistan          AFG
# 2     Afghanistan          AFG
# 3     Afghanistan          AFG
# 4     Afghanistan          AFG
# ...           ...          ...
# 1731     Zimbabwe          ZWE
# 1732     Zimbabwe          ZWE
# 1733     Zimbabwe          ZWE
# 1734     Zimbabwe          ZWE
# 1735     Zimbabwe          ZWE
#
#                                             Series Name        Series Code  \
# 0     Domestic general government health expenditure...  SH.XPD.GHED.PC.CD
# 1     Domestic general government health expenditure...  SH.XPD.GHED.GE.ZS
# 2     Domestic general government health expenditure...  SH.XPD.GHED.GD.ZS
# 3     Domestic general government health expenditure...  SH.XPD.GHED.CH.ZS
# 4     Domestic general government health expenditure...  SH.XPD.PVTD.CH.ZS
# ...                                                 ...                ...
# ...

# %%
health_df['Series Name'].apply(parse_spending)
print(health_df['Series Name'])
# Out:
# 0       Domestic general government health expenditure...
# 1       Domestic general government health expenditure...
# 2       Domestic general government health expenditure...
# 3       Domestic general government health expenditure...
# 4       Domestic general government health expenditure...
#                               ...
# 1731    Domestic general government health expenditure...
# 1732    Domestic general government health expenditure...
# 1733    Domestic general government health expenditure...
# 1734    Domestic general government health expenditure...
# 1735    Domestic general government health expenditure...
# Name: Series Name, Length: 1736, dtype: object

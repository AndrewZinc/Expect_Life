# %%
# Import the dependencies

import pandas as pd

# %%
#data = './Data - Life-expectancy/world_bank-API_SP.DYN.LE00.IN_DS2_en_csv_v2_4700946/API_SP.DYN.LE00.IN_DS2_en_csv_v2_4700946.csv'
data1 = './Data - Life-expectancy/GHO-WPP2022_Demographic_Indicators_Medium/WPP2022_Demographic_Indicators_Medium.csv'

# %% [markdown]
# df = pd.read_csv(data)
# df

# %%
df1 = pd.read_csv(data1)
df1
# Out:
# C:\Users\AZ\anaconda3\envs\Pythondata\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        SortOrder  LocID Notes ISO3_code ISO2_code  SDMX_code  LocTypeID  \
# 0              1    900   NaN       NaN       NaN        1.0          1
# 1              1    900   NaN       NaN       NaN        1.0          1
# 2              1    900   NaN       NaN       NaN        1.0          1
# 3              1    900   NaN       NaN       NaN        1.0          1
# 4              1    900   NaN       NaN       NaN        1.0          1
# ...          ...    ...   ...       ...       ...        ...        ...
# 43467        290    876   2.0       WLF        WF      876.0          4
# 43468        290    876   2.0       WLF        WF      876.0          4
# 43469        290    876   2.0       WLF        WF      876.0          4
# ...

# %%
GHO_medium_df = df1[['LocID','LocTypeID','LocTypeName','ParentID','Location','TPopulation1Jan','Time','LEx']].copy()

# %%
GHO_medium_df
# Out:
#        LocID  LocTypeID   LocTypeName  ParentID                   Location  \
# 0        900          1         World         0                      World
# 1        900          1         World         0                      World
# 2        900          1         World         0                      World
# 3        900          1         World         0                      World
# 4        900          1         World         0                      World
# ...      ...        ...           ...       ...                        ...
# 43467    876          4  Country/Area       957  Wallis and Futuna Islands
# 43468    876          4  Country/Area       957  Wallis and Futuna Islands
# 43469    876          4  Country/Area       957  Wallis and Futuna Islands
# 43470    876          4  Country/Area       957  Wallis and Futuna Islands
# 43471    876          4  Country/Area       957  Wallis and Futuna Islands
#
#        TPopulation1Jan  Time      LEx
# ...

# %%
GHO_country_df = GHO_medium_df[GHO_medium_df['LocTypeName']!='World']
GHO_country_df
# Out:
#        LocID  LocTypeID   LocTypeName  ParentID                   Location  \
# 152     1834         12    SDG region      1828         Sub-Saharan Africa
# 153     1834         12    SDG region      1828         Sub-Saharan Africa
# 154     1834         12    SDG region      1828         Sub-Saharan Africa
# 155     1834         12    SDG region      1828         Sub-Saharan Africa
# 156     1834         12    SDG region      1828         Sub-Saharan Africa
# ...      ...        ...           ...       ...                        ...
# 43467    876          4  Country/Area       957  Wallis and Futuna Islands
# 43468    876          4  Country/Area       957  Wallis and Futuna Islands
# 43469    876          4  Country/Area       957  Wallis and Futuna Islands
# 43470    876          4  Country/Area       957  Wallis and Futuna Islands
# 43471    876          4  Country/Area       957  Wallis and Futuna Islands
#
#        TPopulation1Jan  Time      LEx
# ...

# %%
GHO_country_df = GHO_country_df[GHO_country_df['LocTypeName']=='Country/Area']
GHO_country_df
# Out:
#        LocID  LocTypeID   LocTypeName  ParentID                   Location  \
# 3648     108          4  Country/Area       910                    Burundi
# 3649     108          4  Country/Area       910                    Burundi
# 3650     108          4  Country/Area       910                    Burundi
# 3651     108          4  Country/Area       910                    Burundi
# 3652     108          4  Country/Area       910                    Burundi
# ...      ...        ...           ...       ...                        ...
# 43467    876          4  Country/Area       957  Wallis and Futuna Islands
# 43468    876          4  Country/Area       957  Wallis and Futuna Islands
# 43469    876          4  Country/Area       957  Wallis and Futuna Islands
# 43470    876          4  Country/Area       957  Wallis and Futuna Islands
# 43471    876          4  Country/Area       957  Wallis and Futuna Islands
#
#        TPopulation1Jan  Time      LEx
# ...

# %%
GHO_country_df = GHO_country_df[GHO_country_df['Time']>=1960]
GHO_country_df = GHO_country_df[GHO_country_df['Time']<=2022]
GHO_country_df
# Out:
#        LocID  LocTypeID   LocTypeName  ParentID                   Location  \
# 3658     108          4  Country/Area       910                    Burundi
# 3659     108          4  Country/Area       910                    Burundi
# 3660     108          4  Country/Area       910                    Burundi
# 3661     108          4  Country/Area       910                    Burundi
# 3662     108          4  Country/Area       910                    Burundi
# ...      ...        ...           ...       ...                        ...
# 43388    876          4  Country/Area       957  Wallis and Futuna Islands
# 43389    876          4  Country/Area       957  Wallis and Futuna Islands
# 43390    876          4  Country/Area       957  Wallis and Futuna Islands
# 43391    876          4  Country/Area       957  Wallis and Futuna Islands
# 43392    876          4  Country/Area       957  Wallis and Futuna Islands
#
#        TPopulation1Jan  Time      LEx
# ...

# %%
GHO_country_df = GHO_country_df.drop(['LocTypeID','LocTypeName','ParentID'],1)
GHO_country_df
# Out:
# C:\Users\AZ\anaconda3\envs\Pythondata\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
#        LocID                   Location  TPopulation1Jan  Time      LEx
# 3658     108                    Burundi         2719.733  1960  43.0242
# 3659     108                    Burundi         2773.522  1961  43.2516
# 3660     108                    Burundi         2858.423  1962  43.4411
# 3661     108                    Burundi         2916.374  1963  43.7179
# 3662     108                    Burundi         2979.891  1964  43.9744
# ...      ...                        ...              ...   ...      ...
# 43388    876  Wallis and Futuna Islands           11.870  2018  77.8613
# 43389    876  Wallis and Futuna Islands           11.761  2019  79.6167
# ...

# %%
piv_df = pd.pivot(GHO_country_df, index=['LocID','Location'], columns=['Time'])
piv_df
# Out:
#                                          TPopulation1Jan             \
# Time                                                1960       1961
# LocID Location
# 4     Afghanistan                               8541.748   8703.184
# 8     Albania                                   1682.657   1739.721
# 12    Algeria                                  11279.471  11509.143
# 16    American Samoa                              19.859     20.312
# 20    Andorra                                      9.062      9.823
# ...                                                  ...        ...
# 862   Venezuela (Bolivarian Republic of)        8010.311   8303.563
# 876   Wallis and Futuna Islands                    8.899      8.661
# 882   Samoa                                      111.568    115.103
# 887   Yemen                                     5491.710   5593.209
# 894   Zambia                                    3070.416   3168.443
#
# ...

# %%
data2 = './Data - GDP/API_NY.GDP.MKTP.CD_DS2_en_csv_v2_4701247.csv'
df2 = pd.read_csv(data2)
df2
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  GDP (current US$)
# 1    Africa Eastern and Southern          AFE  GDP (current US$)
# 2                    Afghanistan          AFG  GDP (current US$)
# 3     Africa Western and Central          AFW  GDP (current US$)
# 4                         Angola          AGO  GDP (current US$)
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  GDP (current US$)
# 262                  Yemen, Rep.          YEM  GDP (current US$)
# 263                 South Africa          ZAF  GDP (current US$)
# 264                       Zambia          ZMB  GDP (current US$)
# 265                     Zimbabwe          ZWE  GDP (current US$)
#
#      Indicator Code          1960          1961          1962          1963  \
# 0    NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# ...

# %%
GHO_country_df.to_csv('interim_GHO_LEx-slim.csv', index=False)

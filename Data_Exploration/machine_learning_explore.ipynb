# %%
# Import our dependencies
import pandas as pd
import hvplot.pandas
import plotly.express as px
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder,MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

#  Import and read the charity_data.csv
systems_df = pd.read_csv("country_social_security_systems.csv")
systems_df
# Out:
#                  country                                        system_type  \
# 0                Albania  Universal (medical benefits) and social insura...
# 1                Algeria                            Social insurance system
# 2                Andorra                            Social insurance system
# 3                 Angola  Universal (medical benefits), social insurance...
# 4    Antigua and Barbuda                            Social insurance system
# ..                   ...                                                ...
# 179            Venezuela  Universal (birth grant and medical benefits) a...
# 180             Viet Nam                            Social insurance system
# 181                Yemen  Universal (medical benefits) and employer-liab...
# 182               Zambia  Universal (medical benefits) and employer-liab...
# 183             Zimbabwe  Employer-liability system. Cash sickness and m...
#
#     profile_data_date
# 0        January 2018
# 1        January 2019
# 2        January 2018
# 3        January 2019
# 4           July 2019
# ..                ...
# 179         July 2019
# 180         July 2018
# 181         July 2018
# 182      January 2019
# 183      January 2019
#
# [184 rows x 3 columns]
